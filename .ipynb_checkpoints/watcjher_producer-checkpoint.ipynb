# %%
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %%
import os
import glob
import subprocess
import sys
from multiprocessing import Process
import socket
import sys

from dateutil.parser import parse
from confluent_kafka import Producer
import csv
import pandas as pd

# %%
import datetime
import json
import pandas as pd

# %%
help(FileSystemEventHandler)
# Out:
# Help on class FileSystemEventHandler in module watchdog.events:
#
# class FileSystemEventHandler(builtins.object)
#  |  Base file system event handler that you can override methods from.
#  |
#  |  Methods defined here:
#  |
#  |  dispatch(self, event)
#  |      Dispatches events to the appropriate methods.
#  |
#  |      :param event:
#  |          The event object representing the file system event.
#  |      :type event:
#  |          :class:`FileSystemEvent`
#  |
#  |  on_any_event(self, event)
#  |      Catch-all event handler.
#  |
#  |      :param event:
#  |          The event object representing the file system event.
#  |      :type event:
#  |          :class:`FileSystemEvent`
#  |
#  |  on_created(self, event)
#  |      Called when a file or directory is created.
#  |
#  |      :param event:
#  |          Event representing file/directory creation.
#  |      :type event:
#  |          :class:`DirCreatedEvent` or :class:`FileCreatedEvent`
#  |
#  |  on_deleted(self, event)
#  |      Called when a file or directory is deleted.
#  |
#  |      :param event:
#  |          Event representing file/directory deletion.
#  |      :type event:
#  |          :class:`DirDeletedEvent` or :class:`FileDeletedEvent`
#  |
#  |  on_modified(self, event)
#  |      Called when a file or directory is modified.
#  |
#  |      :param event:
#  |          Event representing file/directory modification.
#  |      :type event:
#  |          :class:`DirModifiedEvent` or :class:`FileModifiedEvent`
#  |
#  |  on_moved(self, event)
#  |      Called when a file or a directory is moved or renamed.
#  |
#  |      :param event:
#  |          Event representing file/directory movement.
#  |      :type event:
#  |          :class:`DirMovedEvent` or :class:`FileMovedEvent`
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
class Watcher:

    def __init__(self, directory=".", handler=FileSystemEventHandler()):
        self.observer = Observer()
        self.handler = handler
        self.directory = directory

    def run(self):
        self.observer.schedule(
            self.handler, self.directory, recursive=True)
        self.observer.start()
        print("\nWatcher Running in {}/\n".format(self.directory))
        try:
            while True:
                time.sleep(1)
        except:
            self.observer.stop()
        self.observer.join()
        print("\nWatcher Terminated\n")


class MyHandler(FileSystemEventHandler):


    def __init__(self,isc_id):
        self.root = 'Orlando_converted'
        self.decoder_path = 'PurdueDecoder.exe'
        self.produce = MessageProducer()
        self.isc_id = isc_id
        self.last_timestamp = None

            
    def on_moved(self, event):
#         print(f"Indi - {event}")
        try:
            path_dest = event.dest_path
            all_split = path_dest.split('/')
            city, year, month, day, isc, filename  = all_split[0], all_split[1], all_split[2], all_split[3], all_split[4],all_split[5] 
            self.check_destination_directory(year, month, day, isc)
            out_file = f"{self.root}/{year}/{month}/{day}/{isc}/{filename}.txt"
            temp = out_file.split('/')[-1].split('_')
            curr_ts = pd.to_datetime(f"{temp[2]}-{temp[3]}-{temp[4]} {temp[5][:2]}:{temp[5][2:4]}:00")
            last_ts  = self.last_timestamp
            
            
            process = subprocess.Popen(["wine", f"{self.decoder_path }", f"{path_dest}", f"{out_file}"])
            (output, err) = process.communicate()  

            #This makes the wait possible
            p_status = process.wait()
            self.produce.generate_messages(isc, out_file)
            
#             produce message from last to current timestamp
            self.produce.generate_message_bit_mask(isc, last_ts, curr_ts)


            if(last_ts is None):
                self.last_timestamp = curr_ts
            if((last_ts is not None)and (curr_ts>last_ts))
                self.last_timestamp= curr_ts
            

        except Exception as e:
            print(f"deocde failed for event {event} due to {e}")
        
#         subprocess.Popen(["cp",f"{path_dest}",f"{self.root}/{year}/{month}/{day}/{isc}"])
        
        
        
    def check_destination_directory(self, year, month, day, isc):
        root = self.root
        
        
        if not os.path.exists(f"{root}/{year}"):
            os.makedirs(f"{root}/{year}")
            
        if not os.path.exists(f"{root}/{year}/{month}"):
            os.makedirs(f"{root}/{year}/{month}")
            
        if not os.path.exists(f"{root}/{year}/{month}/{day}"):
            os.makedirs(f"{root}/{year}/{month}/{day}")
            
        if not os.path.exists(f"{root}/{year}/{month}/{day}/{isc}"):
            os.makedirs(f"{root}/{year}/{month}/{day}/{isc}")

# %%
class ISCWatcher:
    def __init__(self, directory=".", handler=FileSystemEventHandler()):
        self.observer = Observer()
        self.handler = handler
        self.directory = directory
        

    def run(self):
        self.observer.schedule(
            self.handler, self.directory, recursive=False)
        self.observer.start()
        print("\nWatcher Running in {}/\n".format(self.directory))
        try:
            while True:
                time.sleep(1)
        except:
            self.observer.stop()
        self.observer.join()
        print("\nWatcher Terminated\n")
        
class ISChandler(FileSystemEventHandler):
    def __init__(self):
        self.root = 'Orlando_converted'
        self.decoder_path = 'PurdueDecoder.exe'
        self.all_isc_dict = {}
        
    def on_created(self, event):
        print(event.is_directory)
        if(event.is_directory):
            isc_path = event.src_path
            isc_id = event.src_path.split('/')[-1]
            if(isc_id not in self.all_isc_dict):
                print(f"start monitoring {isc_id} at path {isc_path}")
                print(event) # Your code here
                p = Process(target=self.start_process, args=(isc_path,isc_id))
                p.start()
#                 p.join()
#                 start new process and join 

    def start_process(self,dest,isc_id):
        watcher = Watcher(dest, handler = MyHandler(isc_id))
        watcher.run()

# %%
class MessageProducer:
    
    def __init__(self):
        self.file_path = None
        self.topic = 'atspm'
        

        self.conf = {'bootstrap.servers': "localhost:9092",
                'client.id': socket.gethostname()}
        self.producer = Producer(self.conf)
        
        
    def acked(self,err, msg):
#         print(f"called {msg}")
        if err is not None:
            print("Failed to deliver message: %s: %s" % (str(msg.value()), str(err)))
        else:
            print(f"Message produced: {msg.value()}")
            
    def generate_message_bit_mask(self, isc_id, last_ts, curr_ts):
        result = {}

        result['ts']=curr_ts
        result['SignalID']=isc_id
        result['flag']  = 1
        jresult = json.dumps(result)
        self.producer.produce('atspm_bit_mask' , key=isc_id, value=jresult, callback=self.acked)
        
        if((last_ts is not None)and (curr_ts>last_ts)):
            all_ts = pd.date_range(start=last_ts,end=curr_ts, freq= '1min')
            if(len(all_ts)>2):
                for each_ts in all_ts[1:-1]:
                    result = {}
                    result['ts']=each_ts
                    result['SignalID']=isc_id
                    result['flag']  = 0
                    jresult = json.dumps(result)
                    self.producer.produce('atspm_bit_mask' , key=isc_id, value=jresult, callback=self.acked)
            
            
            
            
    def generate_messages(self,isc_id, path):
        df_file = pd.read_csv(path,sep=',',skiprows = 6,header=None,names = ['Timestamp','EventCode','EventParam'] )
        
#         print(f"df_file {df_file.shape}")
        for i,each_row  in df_file.iterrows():
            result = {}
            result["SignalID"] = isc_id
            dt = datetime.datetime.strptime(each_row['Timestamp'], '%m/%d/%Y %H:%M:%S.%f')
            unix_time =  int(time.mktime(dt.timetuple()) * 1000)
            str_time = dt.strftime('%Y-%m-%dT%H:%M:%S.%f')
            result["ts"] = unix_time
            result["EventCode"] = each_row['EventCode']
            result["EventParam"] = each_row['EventParam']

            # Convert dict to json as message format
            jresult = json.dumps(result)
#             print(f"{jresult}")
            self.producer.produce(self.topic , key=isc_id, value=jresult, callback=self.acked)
    
        self.producer.flush()

# %%
temp_path = '/home/yash/interruptions/real_time_pipeline/Orlando_converted/2022/12/02/1020/TRAF_1020_2022_12_02_1759.dat.txt'
isc_id = '1020'

# %%
watcher = ISCWatcher('Orlando/2022/12/04', handler = ISChandler())

# %%
watcher.run()
# Out:
# Watcher Running in Orlando/2022/12/04/
#
# True
# start monitoring 1020 at path Orlando/2022/12/04/1020
# <DirCreatedEvent: event_type=created, src_path='Orlando/2022/12/04/1020', is_directory=True>
#
# Watcher Running in Orlando/2022/12/04/1020/
#
# True
# start monitoring 1025 at path Orlando/2022/12/04/1025
# <DirCreatedEvent: event_type=created, src_path='Orlando/2022/12/04/1025', is_directory=True>
#
# Watcher Running in Orlando/2022/12/04/1025/
#
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0004.dat.E59EDAbD', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0004.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0004.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0001.dat.9e06C873', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0001.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0001.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0002.dat.a3aB68ee', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0002.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0002.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0007.dat.C6F6fED3', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0007.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0007.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0006.dat.6B5C9ea3', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0006.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0006.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0010.dat.2fCC11aB', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0010.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0010.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0003.dat.9Df655d1', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0003.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0003.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0005.dat.372BA0bF', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0005.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0005.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0008.dat.5F1dfCBf', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0008.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0008.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0011.dat.44F4EcD1', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0011.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0011.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0009.dat.EF977bBc', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0009.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0009.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0014.dat.e6BBeCBE', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0014.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0014.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0013.dat.4ADaC7CA', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0013.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0013.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0012.dat.C02cEc21', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0012.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0012.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0015.dat.5a6AeEF5', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0015.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0015.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0016.dat.AdC60EB8', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0016.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0016.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0017.dat.23F5a843', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0017.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0017.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0019.dat.EBa2Ea2a', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0019.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0019.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0000.dat.0338C6E6', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0000.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0000.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0021.dat.C3a325BB', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0021.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0021.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0020.dat.cdBD5beb', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0020.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0020.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0018.dat.CA3f01f4', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0018.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0018.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0022.dat.Db97Ec5E', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0022.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0022.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0023.dat.E6Ab4C0E', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0023.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0023.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0025.dat.75Fe1a7D', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0025.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0025.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0030.dat.dDDD77cf', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0030.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0030.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0027.dat.B3eA410a', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0027.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0027.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0024.dat.69b0dFEd', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0024.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0024.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0029.dat.6Fd602Cf', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0029.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0029.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0028.dat.66bDC90E', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0028.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0028.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0026.dat.90Ad1Aa9', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0026.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_0026.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0035.dat.30b669E7', dest_path='Orlando/2022/12/04/1020/TRAF_1020_2022_12_04_0035.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1020/TRAF_1020_2022_12_04_
dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0337.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0337.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0335.dat.E6f18b3E', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0335.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0335.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0339.dat.AA551e3a', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0339.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0339.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0336.dat.4C78AEfA', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0336.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0336.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0334.dat.f531B29B', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0334.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0334.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0343.dat.Ab61310a', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0343.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0343.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0344.dat.D2b4cd77', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0344.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0344.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0341.dat.B3d27804', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0341.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0341.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0342.dat.c32024cb', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0342.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0342.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0349.dat.Ff8Bb35e', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0349.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0349.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0346.dat.9Ee41134', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0346.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0346.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0348.dat.B5ED3740', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0348.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0348.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0345.dat.d8eefbcD', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0345.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0345.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0347.dat.B9A5772d', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0347.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0347.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0350.dat.f566bbaD', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0350.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0350.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0340.dat.a4263360', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0340.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0340.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0354.dat.37c79ed8', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0354.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0354.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0351.dat.6CBbb0DC', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0351.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0351.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0400.dat.4aDDF500', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0400.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0400.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0352.dat.2a2f5aa5', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0352.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0352.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0359.dat.E68F030D', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0359.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0359.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0353.dat.19c2E4D9', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0353.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0353.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0358.dat.8aB9c588', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0358.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0358.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0356.dat.be58FFa6', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0356.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0356.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0401.dat.Ea9D3Cb1', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0401.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0401.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0402.dat.eb7b4114', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0402.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0402.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0404.dat.C2Cc3023', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0404.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0404.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0355.dat.A2BfAC5B', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0355.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0355.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0403.dat.B9c3CDA2', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0403.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0403.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0406.dat.034fb65f', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0406.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0406.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0408.dat.bD5E780e', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0408.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0408.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0407.dat.A5a9E1bB', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0407.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0407.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0405.dat.196dcBBb', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0405.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0405.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0409.dat.e8BD77b9', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0409.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0409.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0411.dat.Fcfe1319', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0411.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0411.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0410.dat.84E7a89f', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0410.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0410.dat.txt'
# deocde failed for event <FileMovedEvent: src_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0417.dat.F8699Ed3', dest_path='Orlando/2022/12/04/1025/TRAF_1025_2022_12_04_0417.dat', is_directory=False> due to [Errno 2] No such file or directory: 'Orlando_converted/2022/12/04/1025/TRAF_1025_2022_12_04_0417.dat.txt'
#
# Watcher Terminated
#
#
# Watcher Terminated
#
#
# Watcher Terminated
#
#
# Watcher Terminated
#
#
# Watcher Terminated

# %%
tekm = 'Orlando_converted/2022/12/02/1020/TRAF_1020_2022_12_02_1759.dat.txt'

# %%
temp = tekm.split('/')[-1].split('_')

# %%
curr_ts =  pd.to_datetime(f"{temp[2]}-{temp[3]}-{temp[4]} {temp[5][:2]}:{temp[5][2:4]}:00")

# %%
curr_ts
# Out:
# Timestamp('2022-12-02 17:59:00')

# %%
old_ts =  'Orlando_converted/2022/12/02/1020/TRAF_1020_2022_12_02_1757.dat.txt'
temp =  old_ts.split('/')[-1].split('_')
old_ts = pd.to_datetime(f"{temp[2]}-{temp[3]}-{temp[4]} {temp[5][:2]}:{temp[5][2:4]}:00")

# %%
old_ts
# Out:
# Timestamp('2022-12-02 17:57:00')

# %%
curr_ts<old_ts
# Out:
# False

# %%
pd.date_range(start=old_ts,end=curr_ts, freq= '1min')[1:-1]
# Out:
# DatetimeIndex(['2022-12-02 17:58:00'], dtype='datetime64[ns]', freq='T')

# %%
old_ts
# Out:
# Timestamp('2022-12-02 17:57:00')
